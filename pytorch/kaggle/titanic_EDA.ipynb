# %%
import numpy as np
import pandas as pd # data frame
import matplotlib.pyplot as plt # visualization
import seaborn as sns # visualization

plt.style.use('seaborn')
sns.set(font_scale=2.5)

import missingno as msno # null data를 보여줌

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df_train = pd.read_csv('../input/titanic/train.csv')
df_test = pd.read_csv('../input/titanic/test.csv')

# %%
df_train.head(10) # default = 5
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df_train.shape
# Out:
# (891, 12)

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
for col in df_train.columns:
    msg = f'column : {col:>10}\t Percent of NaN value: {100*(df_train[col].isnull().sum()/df_train[col].shape[0]):.2f}%'
    print(msg)
# Out:
# column : PassengerId	 Percent of NaN value: 0.00%
# column :   Survived	 Percent of NaN value: 0.00%
# column :     Pclass	 Percent of NaN value: 0.00%
# column :       Name	 Percent of NaN value: 0.00%
# column :        Sex	 Percent of NaN value: 0.00%
# column :        Age	 Percent of NaN value: 19.87%
# column :      SibSp	 Percent of NaN value: 0.00%
# column :      Parch	 Percent of NaN value: 0.00%
# column :     Ticket	 Percent of NaN value: 0.00%
# column :       Fare	 Percent of NaN value: 0.00%
# column :      Cabin	 Percent of NaN value: 77.10%
# column :   Embarked	 Percent of NaN value: 0.22%

# %%
for col in df_test.columns:
    msg = f'column : {col:>10}\t Percent of NaN value: {100*(df_test[col].isnull().sum()/df_test[col].shape[0]):.2f}%'
    print(msg)
# Out:
# column : PassengerId	 Percent of NaN value: 0.00%
# column :     Pclass	 Percent of NaN value: 0.00%
# column :       Name	 Percent of NaN value: 0.00%
# column :        Sex	 Percent of NaN value: 0.00%
# column :        Age	 Percent of NaN value: 20.57%
# column :      SibSp	 Percent of NaN value: 0.00%
# column :      Parch	 Percent of NaN value: 0.00%
# column :     Ticket	 Percent of NaN value: 0.00%
# column :       Fare	 Percent of NaN value: 0.24%
# column :      Cabin	 Percent of NaN value: 78.23%
# column :   Embarked	 Percent of NaN value: 0.00%

# %%
df_train[col]
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
df_train[col].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Embarked, Length: 891, dtype: bool

# %%
df_train[col].isnull().sum()
# Out:
# 2

# %%
df_train[col].shape
# Out:
# (891,)

# %%
df_train[col].isnull().sum() / df_train[col].shape[0]
# Out:
# 0.002244668911335578

# %%
msno.matrix(df=df_train.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2)) # 분포를 확인 할 수 있다.
# Out:
# <AxesSubplot:>

# %%
df_train.iloc[:, 1]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
msno.bar(df=df_train.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2)) # 개수를 대략적으로 확인할 수 있음
# Out:
# <AxesSubplot:>

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

df_train['Survived']. value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Pie plot - Survived')
ax[0].set_ylabel('')
sns.countplot('Survived', data=df_train, ax=ax[1])
ax[1].set_title('Count plot - Survived')
plt.show()

# %%
df_train['Survived']. value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# ## 2.1 Pclass

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %% [markdown]
# ### Pclass가 1일 때, 136명의 생존자/ 2일 때 87명/ 3일 때119명

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass']).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
df_train['Survived'].unique()
# Out:
# array([0, 1])

# %%
# margins : all column을 추가.
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_9e4e77b6_75dc_11eb_b0de_0242ac130202row0_col0,#T_9e4e77b6_75dc_11eb_b0de_0242ac130202row1_col1,#T_9e4e77b6_75dc_11eb_b0de_0242ac130202row1_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_9e4e77b6_75dc_11eb_b0de_0242ac130202row0_col1{
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }#T_9e4e77b6_75dc_11eb_b0de_0242ac130202row0_col2{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_9e4e77b6_75dc_11eb_b0de_0242ac130202row1_col0{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_9e4e77b6_75dc_11eb_b0de_0242ac130202row2_col0{
#             background-color:  #4292c6;
#             color:  #000000;
#         }#T_9e4e77b6_75dc_11eb_b0de_0242ac130202row2_col1{
#             background-color:  #deebf7;
#             color:  #000000;
#         }#T_9e4e77b6_75dc_11eb_b0de_0242ac130202row2_col2{
#             background-color:  #85bcdc;
#             color:  #000000;
#         }#T_9e4e77b6_75dc_11eb_b0de_0242ac130202row3_col0,#T_9e4e77b6_75dc_11eb_b0de_0242ac130202row3_col1,#T_9e4e77b6_75dc_11eb_b0de_0242ac130202row3_col2{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }</style><table id="T_9e4e77b6_75dc_11eb_b0de_0242ac130202" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e4e77b6_75dc_11eb_b0de_0242ac130202level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_9e4e77b6_75dc_11eb_b0de_0242ac130202row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_9e4e77b6_75dc_11eb_b0de_0242ac130202row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_9e4e77b6_75dc_11eb_b0de_0242ac130202row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_9e4e77b6_75dc_11eb_b0de_0242ac130202level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_9e4e77b6_75dc_11eb_b0de_0242ac130202row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_9e4e77b6_75dc_11eb_b0de_0242ac130202row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_9e4e77b6_75dc_11eb_b0de_0242ac130202row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_9e4e77b6_75dc_11eb_b0de_0242ac130202level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_9e4e77b6_75dc_11eb_b0de_0242ac130202row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_9e4e77b6_75dc_11eb_b0de_0242ac130202row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_9e4e77b6_75dc_11eb_b0de_0242ac130202row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_9e4e77b6_75dc_11eb_b0de_0242ac130202level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_9e4e77b6_75dc_11eb_b0de_0242ac130202row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_9e4e77b6_75dc_11eb_b0de_0242ac130202row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_9e4e77b6_75dc_11eb_b0de_0242ac130202row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
# as_index : Pclass를 index로 한다.
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %%
# as_index가 False이면 두개가 모두 출력 된다.
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False).plot.bar()
# Out:
# <AxesSubplot:>

# %%
y_position = 1.02
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train['Pclass'].value_counts().plot.bar(color=['#CD7F32', '#FFDF00', '#D3D3D3'], ax=ax[0])
ax[0].set_title('Number of passengers By Pclass', y=y_position)
ax[0].set_ylabel('Count')
sns.countplot('Pclass', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Pclass: Survived vs Dead', y=y_position)
plt.show()

# %% [markdown]
# ## 2.2 sex

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')
plt.show()

# %%
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='Sex'>

# %%
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean()
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
pd.crosstab(df_train['Sex'], df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_302ba2cc_75e1_11eb_b0de_0242ac130202row0_col0,#T_302ba2cc_75e1_11eb_b0de_0242ac130202row0_col2,#T_302ba2cc_75e1_11eb_b0de_0242ac130202row1_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_302ba2cc_75e1_11eb_b0de_0242ac130202row0_col1{
#             background-color:  #77bb66;
#             color:  #000000;
#         }#T_302ba2cc_75e1_11eb_b0de_0242ac130202row1_col0{
#             background-color:  #2c9666;
#             color:  #000000;
#         }#T_302ba2cc_75e1_11eb_b0de_0242ac130202row1_col2{
#             background-color:  #8bc566;
#             color:  #000000;
#         }#T_302ba2cc_75e1_11eb_b0de_0242ac130202row2_col0,#T_302ba2cc_75e1_11eb_b0de_0242ac130202row2_col1,#T_302ba2cc_75e1_11eb_b0de_0242ac130202row2_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_302ba2cc_75e1_11eb_b0de_0242ac130202" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_302ba2cc_75e1_11eb_b0de_0242ac130202level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_302ba2cc_75e1_11eb_b0de_0242ac130202row0_col0" class="data row0 col0" >81</td>
#                         <td id="T_302ba2cc_75e1_11eb_b0de_0242ac130202row0_col1" class="data row0 col1" >233</td>
#                         <td id="T_302ba2cc_75e1_11eb_b0de_0242ac130202row0_col2" class="data row0 col2" >314</td>
#             </tr>
#             <tr>
#                         <th id="T_302ba2cc_75e1_11eb_b0de_0242ac130202level0_row1" class="row_heading level0 row1" >male</th>
#                         <td id="T_302ba2cc_75e1_11eb_b0de_0242ac130202row1_col0" class="data row1 col0" >468</td>
#                         <td id="T_302ba2cc_75e1_11eb_b0de_0242ac130202row1_col1" class="data row1 col1" >109</td>
#                         <td id="T_302ba2cc_75e1_11eb_b0de_0242ac130202row1_col2" class="data row1 col2" >577</td>
#             </tr>
#             <tr>
#                         <th id="T_302ba2cc_75e1_11eb_b0de_0242ac130202level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_302ba2cc_75e1_11eb_b0de_0242ac130202row2_col0" class="data row2 col0" >549</td>
#                         <td id="T_302ba2cc_75e1_11eb_b0de_0242ac130202row2_col1" class="data row2 col1" >342</td>
#                         <td id="T_302ba2cc_75e1_11eb_b0de_0242ac130202row2_col2" class="data row2 col2" >891</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## 2.2 Both Sex and Pclass

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=df_train, size=6, aspect=1.5)

# %% [markdown]
# - Lady first,
# - Money brings survival?

# %%
sns.factorplot(x='Sex', y='Survived', hue='Pclass', data=df_train, saturation=5, size=9, aspect=1)

# %%
sns.factorplot(x='Sex', y='Survived', col='Pclass', data=df_train, saturation=5, size=9, aspect=1)

# %% [markdown]
# ## Age

# %%
print(f"제일 나이 많은 탑승객: {df_train['Age'].max():.1f} years.")
print(f"제일 어린 탑승객: {df_train['Age'].min():.1f} years.")
print(f"탑승객 평균 나이: {df_train['Age'].mean():.1f} years.")
# Out:
# 제일 나이 많은 탑승객: 80.0 years.
# 제일 어린 탑승객: 0.4 years.
# 탑승객 평균 나이: 29.7 years.

# %% [markdown]
# ### kdeplot : 데이터 분포를 그려주는 함수

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(df_train[df_train['Survived'] == 1]['Age'], ax=ax)
sns.kdeplot(df_train[df_train['Survived'] == 0]['Age'], ax=ax)
plt.legend(['Survived == 1', 'Survived == 0'])
plt.show()

# %% [markdown]
# ### hist로 보면 아래와 같고 위의 파란선과 분포가 비슷하다.

# %%
df_train[df_train['Survived'] == 1]['Age'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 다양한 indexing

# %%
df_train.iloc[0, :]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
for row in df_train.iterrows():
    break
row
# Out:
# (0,
#  PassengerId                          1
#  Survived                             0
#  Pclass                               3
#  Name           Braund, Mr. Owen Harris
#  Sex                               male
#  Age                                 22
#  SibSp                                1
#  Parch                                0
#  Ticket                       A/5 21171
#  Fare                              7.25
#  Cabin                              NaN
#  Embarked                             S
#  Name: 0, dtype: object)

# %%
df_train[df_train['Survived'] == 1]['Age']
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 875    15.0
# 879    56.0
# 880    25.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 342, dtype: float64

# %% [markdown]
# ## 다양하게 그래프 그리는 법

# %%
f = plt.figure(figsize=(5, 5))
a = np.arange(100)
b = np.sin(a)
plt.plot(b)

# %%
f, ax = plt.subplots(1, 1, figsize=(5, 5))
a = np.arange(100)
b = np.sin(a)
ax.plot(b)

# %%
plt.figure(figsize=(5, 5))
a = np.arange(100)
b = np.sin(a)
plt.plot(b)

# %%
plt.figure(figsize=(15, 8))
df_train['Age'][df_train['Pclass'] == 1].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 2].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 3].plot(kind='kde')

plt.xlabel('Age')
plt.title('Age Distribution within classed')
plt.legend(['1st Class', '2nd Class', '3rd Class'])

# %% [markdown]
# ### hist로 하면 안보인다..

# %%
plt.figure(figsize=(15, 8))
df_train['Age'][df_train['Pclass'] == 1].plot(kind='hist')
df_train['Age'][df_train['Pclass'] == 2].plot(kind='hist')
df_train['Age'][df_train['Pclass'] == 3].plot(kind='hist')

plt.xlabel('Age')
plt.title('Age Distribution within classed')
plt.legend(['1st Class', '2nd Class', '3rd Class'])

# %% [markdown]
# ### 생존확률을 보려면 아래와 같이 작성

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
sns.kdeplot(df_train[(df_train['Survived'] == 0) & (df_train['Pclass'] == 1)]['Age'], ax=ax)
sns.kdeplot(df_train[(df_train['Survived'] == 1) & (df_train['Pclass'] == 1)]['Age'], ax=ax)
plt.title('1st class')
plt.legend(['Survived == 0', 'Survived == 1'])
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
sns.kdeplot(df_train[(df_train['Survived'] == 0) & (df_train['Pclass'] == 2)]['Age'], ax=ax)
sns.kdeplot(df_train[(df_train['Survived'] == 1) & (df_train['Pclass'] == 2)]['Age'], ax=ax)
plt.title('2nd class')
plt.legend(['Survived == 0', 'Survived == 1'])
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
sns.kdeplot(df_train[(df_train['Survived'] == 0) & (df_train['Pclass'] == 3)]['Age'], ax=ax)
sns.kdeplot(df_train[(df_train['Survived'] == 1) & (df_train['Pclass'] == 3)]['Age'], ax=ax)
plt.title('3rd class')
plt.legend(['Survived == 0', 'Survived == 1'])
plt.show()

# %%
# 1~80세까지의 생존률

change_age_range_survival_ratio = []
for i in range(1, 80):
    change_age_range_survival_ratio.append(df_train[df_train['Age'] < i]['Survived'].sum() / len(df_train[df_train['Age'] < i]['Survived']))

plt.figure(figsize=(7, 7))
plt.plot(change_age_range_survival_ratio)
plt.title('Survival rate change depending on range of Age', y=1.02)
plt.ylabel('Survival rate')
plt.xlabel('Range of Age(0~x)')
plt.show()

# %%
# i = 10일 때, 아래 코드는 10살보다 적은 아이들의 생존률이다.

i = 10
df_train[df_train['Age'] < i]['Survived'].sum() / len(df_train[df_train['Age'] < i]['Survived'])
# Out:
# 0.6129032258064516

# %%
len(df_train[df_train['Age'] < i]['Survived'])
# Out:
# 62
