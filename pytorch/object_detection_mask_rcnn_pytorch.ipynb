# %%
import os
import time
import copy
import random
import numpy as np
import pandas as pd

import cv2
import glob
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
import torchvision.transforms as transforms
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

from torch.utils.data import Dataset, DataLoader

# %%
cd drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# ## Hyper-parameter settings

# %%
num_epochs = 10
learning_rate = 5e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ## Define CustomDataset

# %%
class CustomDataset(Dataset):
    def __init__(self, root, transforms):
        self.root = root
        self.transforms = transforms
        self.imgs = list(sorted(os.listdir(os.path.join(root, "PNGImages"))))
        self.masks = list(sorted(os.listdir(os.path.join(root, "PedMasks"))))

    def __getitem__(self, idx):
        img_path = os.path.join(self.root, "PNGImages", self.imgs[idx])
        mask_path = os.path.join(self.root, "PedMasks", self.masks[idx])

        img = Image.open(img_path).convert("RGB")

        mask = Image.open(mask_path)
        mask =np.array(mask)

        obj_ids = np.unique(mask)
        obj_ids = obj_ids[1:]

        masks = mask == obj_ids[:, None, None]

        num_objs = len(obj_ids)
        boxes = []
        for i in range(num_objs):
            pos = np.where(masks[i])
            xmin = np.min(pos[1])
            xmax = np.max(pos[1])
            ymin = np.min(pos[0])
            ymax = np.max(pos[0])
            boxes.append([xmin, ymin, xmax, ymax])

        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.ones((num_objs,), dtype=torch.int64)
        masks = torch.as_tensor(masks, dtype=torch.uint8)

        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["masks"] = masks
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target
    
    def __len__(self):
        return len(self.imgs)

# %% [markdown]
# ## Define Model

# %%
def get_instance_segmentation_model(num_classes):
    model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)

    in_features = model.roi_heads.box_predictor.cls_score.in_features
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
    hidden_layer = 256
    model.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask, hidden_layer, num_classes)

    return model

# %% [markdown]
# ## Make DataLoader

# %%
from engine import train_one_epoch, evaluate
import utils
import transforms as T

def get_transform(train):
    transform = []
    transform.append(T.ToTensor())
    if train:
        transform.append(T.RandomHorizontalFlip(0.5))
    
    return T.Compose(transform)

# %%
train_dataset = CustomDataset('./data/PennFudanPed', get_transform(train=True))
test_dataset = CustomDataset('./data/PennFudanPed', get_transform(train=False))

indices = torch.randperm(len(train_dataset)).tolist()
train_dataset = torch.utils.data.Subset(train_dataset, indices[:-50])
test_dataset = torch.utils.data.Subset(test_dataset, indices[-50:])

train_dataloader = DataLoader(
    train_dataset,
    batch_size=2,
    shuffle=True,
    num_workers=4,
    collate_fn=utils.collate_fn
)

test_dataloader = DataLoader(
    test_dataset,
    batch_size=1,
    shuffle=False,
    num_workers=4,
    collate_fn=utils.collate_fn
)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# ## Train

# %%
num_classes = 2

model = get_instance_segmentation_model(num_classes).to(device)
params = [p for p in model.parameters() if p.requires_grad]
# optimizer = optim.AdamW(params, lr=learning_rate, weight_decay=5e-4)
optimizer = optim.SGD(params, lr=learning_rate, momentum=0.9, weight_decay=5e-4)
lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth" to /root/.cache/torch/hub/checkpoints/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth
#   0%|          | 0.00/170M [00:00<?, ?B/s]

# %%
model.train()
for epoch in range(num_epochs):
    train_one_epoch(model, optimizer, train_dataloader, device, epoch, print_freq=10)

    lr_scheduler.step()

    evaluate(model, test_dataloader, device=device)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Epoch: [0]  [ 0/60]  eta: 0:03:00  lr: 0.000090  loss: 3.8224 (3.8224)  loss_classifier: 0.5587 (0.5587)  loss_box_reg: 0.1845 (0.1845)  loss_mask: 3.0615 (3.0615)  loss_objectness: 0.0170 (0.0170)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 3.0158  data: 1.0704  max mem: 1923
# Epoch: [0]  [10/60]  eta: 0:01:23  lr: 0.000936  loss: 1.7353 (2.1593)  loss_classifier: 0.4533 (0.4003)  loss_box_reg: 0.2443 (0.3043)  loss_mask: 0.7436 (1.4184)  loss_objectness: 0.0202 (0.0305)  loss_rpn_box_reg: 0.0058 (0.0057)  time: 1.6634  data: 0.1072  max mem: 2855
# Epoch: [0]  [20/60]  eta: 0:01:04  lr: 0.001783  loss: 1.0785 (1.5221)  loss_classifier: 0.2275 (0.2958)  loss_box_reg: 0.2930 (0.3028)  loss_mask: 0.4429 (0.8916)  loss_objectness: 0.0164 (0.0244)  loss_rpn_box_reg: 0.0058 (0.0073)  time: 1.5472  data: 0.0122  max mem: 2855
# Epoch: [0]  [30/60]  eta: 0:00:47  lr: 0.002629  loss: 0.6316 (1.2185)  loss_classifier: 0.1116 (0.2306)  loss_box_reg: 0.2738 (0.2902)  loss_mask: 0.2398 (0.6703)  loss_objectness: 0.0100 (0.0202)  loss_rpn_box_reg: 0.0057 (0.0072)  time: 1.5474  data: 0.0130  max mem: 3040
# Epoch: [0]  [40/60]  eta: 0:00:30  lr: 0.003476  loss: 0.4134 (1.0035)  loss_classifier: 0.0517 (0.1842)  loss_box_reg: 0.1832 (0.2522)  loss_mask: 0.1784 (0.5443)  loss_objectness: 0.0079 (0.0166)  loss_rpn_box_reg: 0.0036 (0.0062)  time: 1.4567  data: 0.0148  max mem: 3040
# Epoch: [0]  [50/60]  eta: 0:00:15  lr: 0.004323  loss: 0.3421 (0.8733)  loss_classifier: 0.0357 (0.1566)  loss_box_reg: 0.1222 (0.2265)  loss_mask: 0.1588 (0.4705)  loss_objectness: 0.0021 (0.0140)  loss_rpn_box_reg: 0.0031 (0.0058)  time: 1.4583  data: 0.0144  max mem: 3040
# Epoch: [0]  [59/60]  eta: 0:00:01  lr: 0.005000  loss: 0.3421 (0.7952)  loss_classifier: 0.0456 (0.1402)  loss_box_reg: 0.1153 (0.2106)  loss_mask: 0.1615 (0.4262)  loss_objectness: 0.0024 (0.0125)  loss_rpn_box_reg: 0.0033 (0.0057)  time: 1.9540  data: 0.4480  max mem: 3040
# Epoch: [0] Total time: 0:01:40 (1.6819 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:32  model_time: 0.3903 (0.3903)  evaluator_time: 0.0195 (0.0195)  time: 0.6454  data: 0.2343  max mem: 3040
# Test:  [49/50]  eta: 0:00:00  model_time: 0.3402 (0.3516)  evaluator_time: 0.0172 (0.0223)  time: 0.3840  data: 0.0070  max mem: 3040
# Test: Total time: 0:00:19 (0.3902 s / it)
# Averaged stats: model_time: 0.3402 (0.3516)  evaluator_time: 0.0172 (0.0223)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.716
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.994
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.834
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.719
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.715
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.332
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.764
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.840
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.761
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.718
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.994
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.873
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.549
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.724
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.332
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.751
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.740
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.752
# Epoch: [1]  [ 0/60]  eta: 0:01:55  lr: 0.005000  loss: 0.2711 (0.2711)  loss_classifier: 0.0355 (0.0355)  loss_box_reg: 0.0891 (0.0891)  loss_mask: 0.1396 (0.1396)  loss_objectness: 0.0020 (0.0020)  loss_rpn_box_reg: 0.0049 (0.0049)  time: 1.9174  data: 0.4031  max mem: 3040
# Epoch: [1]  [10/60]  eta: 0:01:19  lr: 0.005000  loss: 0.2712 (0.3163)  loss_classifier: 0.0377 (0.0458)  loss_box_reg: 0.0895 (0.0994)  loss_mask: 0.1437 (0.1622)  loss_objectness: 0.0013 (0.0019)  loss_rpn_box_reg: 0.0049 (0.0068)  time: 1.5854  data: 0.0569  max mem: 3040
# Epoch: [1]  [20/60]  eta: 0:01:01  lr: 0.005000  loss: 0.2919 (0.3116)  loss_classifier: 0.0381 (0.0441)  loss_box_reg: 0.0931 (0.0971)  loss_mask: 0.1521 (0.1622)  loss_objectness: 0.0015 (0.0020)  loss_rpn_box_reg: 0.0046 (0.0062)  time: 1.5240  data: 0.0174  max mem: 3040
# Epoch: [1]  [30/60]  eta: 0:00:45  lr: 0.005000  loss: 0.2892 (0.2941)  loss_classifier: 0.0337 (0.0403)  loss_box_reg: 0.0735 (0.0883)  loss_mask: 0.1499 (0.1582)  loss_objectness: 0.0011 (0.0017)  loss_rpn_box_reg: 0.0037 (0.0056)  time: 1.4926  data: 0.0130  max mem: 3040
# Epoch: [1]  [40/60]  eta: 0:00:30  lr: 0.005000  loss: 0.2227 (0.2805)  loss_classifier: 0.0328 (0.0375)  loss_box_reg: 0.0621 (0.0822)  loss_mask: 0.1321 (0.1542)  loss_objectness: 0.0005 (0.0017)  loss_rpn_box_reg: 0.0030 (0.0050)  time: 1.5014  data: 0.0130  max mem: 3040
# Epoch: [1]  [50/60]  eta: 0:00:15  lr: 0.005000  loss: 0.2711 (0.2842)  loss_classifier: 0.0333 (0.0395)  loss_box_reg: 0.0705 (0.0841)  loss_mask: 0.1335 (0.1532)  loss_objectness: 0.0011 (0.0019)  loss_rpn_box_reg: 0.0037 (0.0055)  time: 1.5380  data: 0.0130  max mem: 3040
# Epoch: [1]  [59/60]  eta: 0:00:01  lr: 0.005000  loss: 0.2711 (0.2788)  loss_classifier: 0.0381 (0.0383)  loss_box_reg: 0.0768 (0.0804)  loss_mask: 0.1335 (0.1528)  loss_objectness: 0.0012 (0.0018)  loss_rpn_box_reg: 0.0044 (0.0054)  time: 1.5569  data: 0.0126  max mem: 3076
# Epoch: [1] Total time: 0:01:31 (1.5319 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:32  model_time: 0.4345 (0.4345)  evaluator_time: 0.0081 (0.0081)  time: 0.6442  data: 0.2001  max mem: 3076
# Test:  [49/50]  eta: 0:00:00  model_time: 0.3290 (0.3305)  evaluator_time: 0.0052 (0.0071)  time: 0.3456  data: 0.0057  max mem: 3076
# Test: Total time: 0:00:17 (0.3504 s / it)
# Averaged stats: model_time: 0.3290 (0.3305)  evaluator_time: 0.0052 (0.0071)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.733
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.910
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.776
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.343
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.780
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.780
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.779
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.713
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.984
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.900
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.766
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.713
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.338
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.754
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.754
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.780
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.753
# Epoch: [2]  [ 0/60]  eta: 0:01:42  lr: 0.005000  loss: 0.2008 (0.2008)  loss_classifier: 0.0222 (0.0222)  loss_box_reg: 0.0454 (0.0454)  loss_mask: 0.1288 (0.1288)  loss_objectness: 0.0008 (0.0008)  loss_rpn_box_reg: 0.0036 (0.0036)  time: 1.7014  data: 0.3494  max mem: 3076
# Epoch: [2]  [10/60]  eta: 0:01:18  lr: 0.005000  loss: 0.2008 (0.2178)  loss_classifier: 0.0293 (0.0304)  loss_box_reg: 0.0467 (0.0567)  loss_mask: 0.1217 (0.1270)  loss_objectness: 0.0004 (0.0006)  loss_rpn_box_reg: 0.0027 (0.0032)  time: 1.5682  data: 0.0428  max mem: 3132
# Epoch: [2]  [20/60]  eta: 0:01:02  lr: 0.005000  loss: 0.2112 (0.2324)  loss_classifier: 0.0323 (0.0336)  loss_box_reg: 0.0538 (0.0628)  loss_mask: 0.1239 (0.1312)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0032 (0.0037)  time: 1.5442  data: 0.0123  max mem: 3132
# Epoch: [2]  [30/60]  eta: 0:00:47  lr: 0.005000  loss: 0.2333 (0.2318)  loss_classifier: 0.0316 (0.0328)  loss_box_reg: 0.0583 (0.0613)  loss_mask: 0.1282 (0.1329)  loss_objectness: 0.0005 (0.0010)  loss_rpn_box_reg: 0.0035 (0.0039)  time: 1.5925  data: 0.0124  max mem: 3132
# Epoch: [2]  [40/60]  eta: 0:00:31  lr: 0.005000  loss: 0.2386 (0.2394)  loss_classifier: 0.0318 (0.0346)  loss_box_reg: 0.0587 (0.0630)  loss_mask: 0.1399 (0.1366)  loss_objectness: 0.0007 (0.0011)  loss_rpn_box_reg: 0.0033 (0.0041)  time: 1.5877  data: 0.0122  max mem: 3132
# Epoch: [2]  [50/60]  eta: 0:00:15  lr: 0.005000  loss: 0.2179 (0.2320)  loss_classifier: 0.0296 (0.0329)  loss_box_reg: 0.0531 (0.0603)  loss_mask: 0.1259 (0.1338)  loss_objectness: 0.0007 (0.0010)  loss_rpn_box_reg: 0.0030 (0.0040)  time: 1.5068  data: 0.0120  max mem: 3132
# Epoch: [2]  [59/60]  eta: 0:00:01  lr: 0.005000  loss: 0.1957 (0.2276)  loss_classifier: 0.0208 (0.0313)  loss_box_reg: 0.0462 (0.0586)  loss_mask: 0.1165 (0.1327)  loss_objectness: 0.0003 (0.0011)  loss_rpn_box_reg: 0.0024 (0.0039)  time: 1.5000  data: 0.0122  max mem: 3223
# Epoch: [2] Total time: 0:01:33 (1.5525 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:38  model_time: 0.4493 (0.4493)  evaluator_time: 0.0093 (0.0093)  time: 0.7630  data: 0.3029  max mem: 3223
# Test:  [49/50]  eta: 0:00:00  model_time: 0.3332 (0.3313)  evaluator_time: 0.0051 (0.0071)  time: 0.3483  data: 0.0060  max mem: 3223
# Test: Total time: 0:00:17 (0.3528 s / it)
# Averaged stats: model_time: 0.3332 (0.3313)  evaluator_time: 0.0051 (0.0071)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.808
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.962
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.876
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.809
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.381
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.849
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.849
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.846
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.761
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.983
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.925
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.738
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.764
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.793
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.793
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.793
# Epoch: [3]  [ 0/60]  eta: 0:01:50  lr: 0.000500  loss: 0.2983 (0.2983)  loss_classifier: 0.0260 (0.0260)  loss_box_reg: 0.0598 (0.0598)  loss_mask: 0.2073 (0.2073)  loss_objectness: 0.0008 (0.0008)  loss_rpn_box_reg: 0.0043 (0.0043)  time: 1.8414  data: 0.3876  max mem: 3223
# Epoch: [3]  [10/60]  eta: 0:01:14  lr: 0.000500  loss: 0.1808 (0.1853)  loss_classifier: 0.0250 (0.0248)  loss_box_reg: 0.0421 (0.0411)  loss_mask: 0.1081 (0.1161)  loss_objectness: 0.0007 (0.0009)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.4958  data: 0.0459  max mem: 3223
# Epoch: [3]  [20/60]  eta: 0:01:00  lr: 0.000500  loss: 0.1912 (0.2100)  loss_classifier: 0.0251 (0.0266)  loss_box_reg: 0.0425 (0.0486)  loss_mask: 0.1148 (0.1304)  loss_objectness: 0.0006 (0.0012)  loss_rpn_box_reg: 0.0026 (0.0031)  time: 1.5000  data: 0.0118  max mem: 3223
# Epoch: [3]  [30/60]  eta: 0:00:45  lr: 0.000500  loss: 0.2140 (0.2075)  loss_classifier: 0.0286 (0.0266)  loss_box_reg: 0.0462 (0.0473)  loss_mask: 0.1287 (0.1291)  loss_objectness: 0.0005 (0.0014)  loss_rpn_box_reg: 0.0028 (0.0031)  time: 1.5446  data: 0.0122  max mem: 3223
# Epoch: [3]  [40/60]  eta: 0:00:30  lr: 0.000500  loss: 0.1786 (0.2071)  loss_classifier: 0.0286 (0.0274)  loss_box_reg: 0.0403 (0.0466)  loss_mask: 0.1088 (0.1286)  loss_objectness: 0.0003 (0.0011)  loss_rpn_box_reg: 0.0028 (0.0034)  time: 1.5599  data: 0.0124  max mem: 3235
# Epoch: [3]  [50/60]  eta: 0:00:15  lr: 0.000500  loss: 0.1695 (0.2034)  loss_classifier: 0.0250 (0.0274)  loss_box_reg: 0.0308 (0.0452)  loss_mask: 0.1130 (0.1266)  loss_objectness: 0.0003 (0.0010)  loss_rpn_box_reg: 0.0023 (0.0032)  time: 1.5183  data: 0.0127  max mem: 3235
# Epoch: [3]  [59/60]  eta: 0:00:01  lr: 0.000500  loss: 0.1701 (0.1995)  loss_classifier: 0.0221 (0.0274)  loss_box_reg: 0.0307 (0.0436)  loss_mask: 0.1159 (0.1244)  loss_objectness: 0.0003 (0.0010)  loss_rpn_box_reg: 0.0018 (0.0032)  time: 1.5205  data: 0.0126  max mem: 3235
# Epoch: [3] Total time: 0:01:31 (1.5257 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:37  model_time: 0.4502 (0.4502)  evaluator_time: 0.0088 (0.0088)  time: 0.7434  data: 0.2828  max mem: 3235
# Test:  [49/50]  eta: 0:00:00  model_time: 0.3268 (0.3324)  evaluator_time: 0.0051 (0.0071)  time: 0.3477  data: 0.0062  max mem: 3235
# Test: Total time: 0:00:17 (0.3543 s / it)
# Averaged stats: model_time: 0.3268 (0.3324)  evaluator_time: 0.0051 (0.0071)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.821
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.950
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.876
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.821
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.380
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.861
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.861
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.859
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.770
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.712
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.774
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.356
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.803
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.803
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.804
# Epoch: [4]  [ 0/60]  eta: 0:01:52  lr: 0.000500  loss: 0.2262 (0.2262)  loss_classifier: 0.0228 (0.0228)  loss_box_reg: 0.0534 (0.0534)  loss_mask: 0.1444 (0.1444)  loss_objectness: 0.0011 (0.0011)  loss_rpn_box_reg: 0.0046 (0.0046)  time: 1.8727  data: 0.3940  max mem: 3235
# Epoch: [4]  [10/60]  eta: 0:01:19  lr: 0.000500  loss: 0.1677 (0.1894)  loss_classifier: 0.0260 (0.0276)  loss_box_reg: 0.0336 (0.0373)  loss_mask: 0.1154 (0.1199)  loss_objectness: 0.0003 (0.0013)  loss_rpn_box_reg: 0.0035 (0.0033)  time: 1.5890  data: 0.0450  max mem: 3235
# Epoch: [4]  [20/60]  eta: 0:01:02  lr: 0.000500  loss: 0.1664 (0.1824)  loss_classifier: 0.0246 (0.0261)  loss_box_reg: 0.0313 (0.0372)  loss_mask: 0.1080 (0.1148)  loss_objectness: 0.0004 (0.0013)  loss_rpn_box_reg: 0.0024 (0.0030)  time: 1.5466  data: 0.0114  max mem: 3235
# Epoch: [4]  [30/60]  eta: 0:00:45  lr: 0.000500  loss: 0.1672 (0.1833)  loss_classifier: 0.0232 (0.0253)  loss_box_reg: 0.0301 (0.0357)  loss_mask: 0.1064 (0.1182)  loss_objectness: 0.0003 (0.0011)  loss_rpn_box_reg: 0.0023 (0.0030)  time: 1.4883  data: 0.0129  max mem: 3235
# Epoch: [4]  [40/60]  eta: 0:00:30  lr: 0.000500  loss: 0.1623 (0.1818)  loss_classifier: 0.0214 (0.0244)  loss_box_reg: 0.0278 (0.0352)  loss_mask: 0.1118 (0.1184)  loss_objectness: 0.0003 (0.0011)  loss_rpn_box_reg: 0.0016 (0.0027)  time: 1.4677  data: 0.0128  max mem: 3235
# Epoch: [4]  [50/60]  eta: 0:00:15  lr: 0.000500  loss: 0.1700 (0.1848)  loss_classifier: 0.0221 (0.0257)  loss_box_reg: 0.0283 (0.0367)  loss_mask: 0.1137 (0.1185)  loss_objectness: 0.0006 (0.0012)  loss_rpn_box_reg: 0.0015 (0.0027)  time: 1.5151  data: 0.0127  max mem: 3235
# Epoch: [4]  [59/60]  eta: 0:00:01  lr: 0.000500  loss: 0.1959 (0.1853)  loss_classifier: 0.0300 (0.0259)  loss_box_reg: 0.0394 (0.0377)  loss_mask: 0.1151 (0.1178)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0030 (0.0028)  time: 1.5991  data: 0.0122  max mem: 3235
# Epoch: [4] Total time: 0:01:32 (1.5413 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:36  model_time: 0.4477 (0.4477)  evaluator_time: 0.0090 (0.0090)  time: 0.7334  data: 0.2752  max mem: 3235
# Test:  [49/50]  eta: 0:00:00  model_time: 0.3292 (0.3307)  evaluator_time: 0.0056 (0.0070)  time: 0.3473  data: 0.0060  max mem: 3235
# Test: Total time: 0:00:17 (0.3525 s / it)
# Averaged stats: model_time: 0.3292 (0.3307)  evaluator_time: 0.0056 (0.0070)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.824
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.949
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.876
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.824
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.383
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.861
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.861
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.859
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.766
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.691
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.770
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.356
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.802
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.802
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.802
# Epoch: [5]  [ 0/60]  eta: 0:02:29  lr: 0.000500  loss: 0.2030 (0.2030)  loss_classifier: 0.0450 (0.0450)  loss_box_reg: 0.0584 (0.0584)  loss_mask: 0.0955 (0.0955)  loss_objectness: 0.0007 (0.0007)  loss_rpn_box_reg: 0.0034 (0.0034)  time: 2.4838  data: 0.5070  max mem: 3235
# Epoch: [5]  [10/60]  eta: 0:01:16  lr: 0.000500  loss: 0.1726 (0.1807)  loss_classifier: 0.0268 (0.0295)  loss_box_reg: 0.0295 (0.0322)  loss_mask: 0.1079 (0.1148)  loss_objectness: 0.0007 (0.0020)  loss_rpn_box_reg: 0.0024 (0.0022)  time: 1.5340  data: 0.0546  max mem: 3235
# Epoch: [5]  [20/60]  eta: 0:01:02  lr: 0.000500  loss: 0.1777 (0.1854)  loss_classifier: 0.0252 (0.0263)  loss_box_reg: 0.0270 (0.0339)  loss_mask: 0.1167 (0.1215)  loss_objectness: 0.0004 (0.0012)  loss_rpn_box_reg: 0.0019 (0.0023)  time: 1.5048  data: 0.0107  max mem: 3235
# Epoch: [5]  [30/60]  eta: 0:00:47  lr: 0.000500  loss: 0.1777 (0.1833)  loss_classifier: 0.0237 (0.0262)  loss_box_reg: 0.0316 (0.0342)  loss_mask: 0.1167 (0.1194)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.6028  data: 0.0127  max mem: 3235
# Epoch: [5]  [40/60]  eta: 0:00:31  lr: 0.000500  loss: 0.1744 (0.1897)  loss_classifier: 0.0263 (0.0275)  loss_box_reg: 0.0335 (0.0375)  loss_mask: 0.1145 (0.1210)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0031 (0.0029)  time: 1.6250  data: 0.0139  max mem: 3235
# Epoch: [5]  [50/60]  eta: 0:00:15  lr: 0.000500  loss: 0.1734 (0.1853)  loss_classifier: 0.0237 (0.0262)  loss_box_reg: 0.0350 (0.0364)  loss_mask: 0.1065 (0.1190)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0020 (0.0028)  time: 1.5600  data: 0.0137  max mem: 3235
# Epoch: [5]  [59/60]  eta: 0:00:01  lr: 0.000500  loss: 0.1639 (0.1832)  loss_classifier: 0.0224 (0.0259)  loss_box_reg: 0.0290 (0.0362)  loss_mask: 0.1021 (0.1176)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0019 (0.0027)  time: 1.5157  data: 0.0130  max mem: 3235
# Epoch: [5] Total time: 0:01:34 (1.5668 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:35  model_time: 0.4423 (0.4423)  evaluator_time: 0.0098 (0.0098)  time: 0.7177  data: 0.2633  max mem: 3235
# Test:  [49/50]  eta: 0:00:00  model_time: 0.3328 (0.3322)  evaluator_time: 0.0055 (0.0071)  time: 0.3479  data: 0.0062  max mem: 3235
# Test: Total time: 0:00:17 (0.3536 s / it)
# Averaged stats: model_time: 0.3328 (0.3322)  evaluator_time: 0.0055 (0.0071)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.829
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.950
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.837
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.830
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.383
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.863
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.863
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.860
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.863
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.769
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.674
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.772
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.804
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.804
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.804
# Epoch: [6]  [ 0/60]  eta: 0:01:48  lr: 0.000050  loss: 0.1232 (0.1232)  loss_classifier: 0.0122 (0.0122)  loss_box_reg: 0.0106 (0.0106)  loss_mask: 0.0997 (0.0997)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 1.8105  data: 0.3339  max mem: 3235
# Epoch: [6]  [10/60]  eta: 0:01:15  lr: 0.000050  loss: 0.1640 (0.1646)  loss_classifier: 0.0227 (0.0226)  loss_box_reg: 0.0293 (0.0302)  loss_mask: 0.1034 (0.1093)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0014 (0.0020)  time: 1.5063  data: 0.0404  max mem: 3235
# Epoch: [6]  [20/60]  eta: 0:00:59  lr: 0.000050  loss: 0.1648 (0.1768)  loss_classifier: 0.0240 (0.0243)  loss_box_reg: 0.0342 (0.0347)  loss_mask: 0.1057 (0.1147)  loss_objectness: 0.0003 (0.0005)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.4634  data: 0.0122  max mem: 3235
# Epoch: [6]  [30/60]  eta: 0:00:45  lr: 0.000050  loss: 0.1630 (0.1724)  loss_classifier: 0.0240 (0.0236)  loss_box_reg: 0.0290 (0.0323)  loss_mask: 0.1075 (0.1136)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0021 (0.0024)  time: 1.5053  data: 0.0134  max mem: 3235
# Epoch: [6]  [40/60]  eta: 0:00:30  lr: 0.000050  loss: 0.1523 (0.1731)  loss_classifier: 0.0215 (0.0240)  loss_box_reg: 0.0233 (0.0327)  loss_mask: 0.1081 (0.1131)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0018 (0.0025)  time: 1.5907  data: 0.0135  max mem: 3235
# Epoch: [6]  [50/60]  eta: 0:00:15  lr: 0.000050  loss: 0.1806 (0.1793)  loss_classifier: 0.0293 (0.0254)  loss_box_reg: 0.0338 (0.0344)  loss_mask: 0.1106 (0.1163)  loss_objectness: 0.0004 (0.0008)  loss_rpn_box_reg: 0.0014 (0.0025)  time: 1.5778  data: 0.0132  max mem: 3235
# Epoch: [6]  [59/60]  eta: 0:00:01  lr: 0.000050  loss: 0.1814 (0.1785)  loss_classifier: 0.0276 (0.0248)  loss_box_reg: 0.0357 (0.0343)  loss_mask: 0.1183 (0.1159)  loss_objectness: 0.0004 (0.0008)  loss_rpn_box_reg: 0.0019 (0.0026)  time: 1.5908  data: 0.0125  max mem: 3235
# Epoch: [6] Total time: 0:01:33 (1.5507 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:37  model_time: 0.4452 (0.4452)  evaluator_time: 0.0081 (0.0081)  time: 0.7551  data: 0.3004  max mem: 3235
# Test:  [49/50]  eta: 0:00:00  model_time: 0.3268 (0.3303)  evaluator_time: 0.0053 (0.0071)  time: 0.3468  data: 0.0061  max mem: 3235
# Test: Total time: 0:00:17 (0.3523 s / it)
# Averaged stats: model_time: 0.3268 (0.3303)  evaluator_time: 0.0053 (0.0071)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.829
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.950
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.837
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.829
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.382
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.863
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.863
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.860
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.863
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.768
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.924
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.691
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.771
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.356
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.804
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.804
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.804
# Epoch: [7]  [ 0/60]  eta: 0:01:47  lr: 0.000050  loss: 0.1246 (0.1246)  loss_classifier: 0.0225 (0.0225)  loss_box_reg: 0.0151 (0.0151)  loss_mask: 0.0860 (0.0860)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 1.7864  data: 0.3844  max mem: 3235
# Epoch: [7]  [10/60]  eta: 0:01:12  lr: 0.000050  loss: 0.1552 (0.1618)  loss_classifier: 0.0205 (0.0206)  loss_box_reg: 0.0223 (0.0273)  loss_mask: 0.1141 (0.1120)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0011 (0.0015)  time: 1.4557  data: 0.0429  max mem: 3235
# Epoch: [7]  [20/60]  eta: 0:00:58  lr: 0.000050  loss: 0.1624 (0.1733)  loss_classifier: 0.0202 (0.0233)  loss_box_reg: 0.0223 (0.0307)  loss_mask: 0.1141 (0.1160)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0022 (0.0026)  time: 1.4532  data: 0.0105  max mem: 3235
# Epoch: [7]  [30/60]  eta: 0:00:45  lr: 0.000050  loss: 0.1643 (0.1787)  loss_classifier: 0.0223 (0.0260)  loss_box_reg: 0.0281 (0.0329)  loss_mask: 0.1143 (0.1167)  loss_objectness: 0.0003 (0.0005)  loss_rpn_box_reg: 0.0023 (0.0026)  time: 1.5715  data: 0.0124  max mem: 3235
# Epoch: [7]  [40/60]  eta: 0:00:30  lr: 0.000050  loss: 0.1642 (0.1759)  loss_classifier: 0.0252 (0.0261)  loss_box_reg: 0.0281 (0.0330)  loss_mask: 0.1050 (0.1134)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0018 (0.0025)  time: 1.6120  data: 0.0125  max mem: 3235
# Epoch: [7]  [50/60]  eta: 0:00:15  lr: 0.000050  loss: 0.1625 (0.1810)  loss_classifier: 0.0250 (0.0267)  loss_box_reg: 0.0286 (0.0345)  loss_mask: 0.1065 (0.1161)  loss_objectness: 0.0005 (0.0010)  loss_rpn_box_reg: 0.0018 (0.0027)  time: 1.5516  data: 0.0136  max mem: 3235
# Epoch: [7]  [59/60]  eta: 0:00:01  lr: 0.000050  loss: 0.1625 (0.1803)  loss_classifier: 0.0229 (0.0264)  loss_box_reg: 0.0289 (0.0347)  loss_mask: 0.1112 (0.1157)  loss_objectness: 0.0005 (0.0009)  loss_rpn_box_reg: 0.0019 (0.0026)  time: 1.5594  data: 0.0139  max mem: 3235
# Epoch: [7] Total time: 0:01:32 (1.5424 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:36  model_time: 0.4504 (0.4504)  evaluator_time: 0.0084 (0.0084)  time: 0.7332  data: 0.2730  max mem: 3235
# Test:  [49/50]  eta: 0:00:00  model_time: 0.3300 (0.3321)  evaluator_time: 0.0051 (0.0070)  time: 0.3472  data: 0.0064  max mem: 3235
# Test: Total time: 0:00:17 (0.3532 s / it)
# Averaged stats: model_time: 0.3300 (0.3321)  evaluator_time: 0.0051 (0.0070)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.830
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.950
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.837
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.831
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.383
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.864
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.864
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.860
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.864
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.769
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.924
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.690
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.773
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.356
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.805
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.805
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.805
# Epoch: [8]  [ 0/60]  eta: 0:01:43  lr: 0.000050  loss: 0.1355 (0.1355)  loss_classifier: 0.0135 (0.0135)  loss_box_reg: 0.0116 (0.0116)  loss_mask: 0.1095 (0.1095)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 1.7260  data: 0.4039  max mem: 3235
# Epoch: [8]  [10/60]  eta: 0:01:22  lr: 0.000050  loss: 0.1590 (0.1671)  loss_classifier: 0.0239 (0.0241)  loss_box_reg: 0.0249 (0.0316)  loss_mask: 0.1005 (0.1085)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.6476  data: 0.0482  max mem: 3235
# Epoch: [8]  [20/60]  eta: 0:01:04  lr: 0.000050  loss: 0.1679 (0.1760)  loss_classifier: 0.0247 (0.0254)  loss_box_reg: 0.0304 (0.0335)  loss_mask: 0.1060 (0.1137)  loss_objectness: 0.0003 (0.0005)  loss_rpn_box_reg: 0.0028 (0.0028)  time: 1.6198  data: 0.0124  max mem: 3235
# Epoch: [8]  [30/60]  eta: 0:00:48  lr: 0.000050  loss: 0.1683 (0.1758)  loss_classifier: 0.0231 (0.0247)  loss_box_reg: 0.0297 (0.0330)  loss_mask: 0.1093 (0.1145)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.6176  data: 0.0125  max mem: 3235
# Epoch: [8]  [40/60]  eta: 0:00:32  lr: 0.000050  loss: 0.1660 (0.1738)  loss_classifier: 0.0222 (0.0245)  loss_box_reg: 0.0255 (0.0323)  loss_mask: 0.1070 (0.1135)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0020 (0.0026)  time: 1.5846  data: 0.0129  max mem: 3235
# Epoch: [8]  [50/60]  eta: 0:00:15  lr: 0.000050  loss: 0.1609 (0.1767)  loss_classifier: 0.0216 (0.0246)  loss_box_reg: 0.0238 (0.0337)  loss_mask: 0.1129 (0.1150)  loss_objectness: 0.0005 (0.0008)  loss_rpn_box_reg: 0.0022 (0.0026)  time: 1.5020  data: 0.0133  max mem: 3235
# Epoch: [8]  [59/60]  eta: 0:00:01  lr: 0.000050  loss: 0.1754 (0.1778)  loss_classifier: 0.0254 (0.0250)  loss_box_reg: 0.0286 (0.0334)  loss_mask: 0.1164 (0.1159)  loss_objectness: 0.0005 (0.0009)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.5146  data: 0.0132  max mem: 3520
# Epoch: [8] Total time: 0:01:34 (1.5760 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:36  model_time: 0.4662 (0.4662)  evaluator_time: 0.0085 (0.0085)  time: 0.7221  data: 0.2458  max mem: 3520
# Test:  [49/50]  eta: 0:00:00  model_time: 0.3316 (0.3309)  evaluator_time: 0.0050 (0.0069)  time: 0.3445  data: 0.0060  max mem: 3520
# Test: Total time: 0:00:17 (0.3515 s / it)
# Averaged stats: model_time: 0.3316 (0.3309)  evaluator_time: 0.0050 (0.0069)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.830
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.950
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.837
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.830
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.383
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.863
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.863
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.860
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.863
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.769
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.690
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.772
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.356
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.803
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.803
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.803
# Epoch: [9]  [ 0/60]  eta: 0:02:13  lr: 0.000005  loss: 0.2308 (0.2308)  loss_classifier: 0.0306 (0.0306)  loss_box_reg: 0.0368 (0.0368)  loss_mask: 0.1606 (0.1606)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 2.2236  data: 0.4984  max mem: 3520
# Epoch: [9]  [10/60]  eta: 0:01:14  lr: 0.000005  loss: 0.1810 (0.1966)  loss_classifier: 0.0253 (0.0262)  loss_box_reg: 0.0368 (0.0385)  loss_mask: 0.1163 (0.1287)  loss_objectness: 0.0005 (0.0007)  loss_rpn_box_reg: 0.0022 (0.0025)  time: 1.4920  data: 0.0530  max mem: 3520
# Epoch: [9]  [20/60]  eta: 0:01:02  lr: 0.000005  loss: 0.1714 (0.1878)  loss_classifier: 0.0252 (0.0270)  loss_box_reg: 0.0352 (0.0389)  loss_mask: 0.1070 (0.1181)  loss_objectness: 0.0005 (0.0012)  loss_rpn_box_reg: 0.0022 (0.0026)  time: 1.5235  data: 0.0112  max mem: 3520
# Epoch: [9]  [30/60]  eta: 0:00:47  lr: 0.000005  loss: 0.1709 (0.1868)  loss_classifier: 0.0248 (0.0263)  loss_box_reg: 0.0352 (0.0386)  loss_mask: 0.1053 (0.1180)  loss_objectness: 0.0003 (0.0012)  loss_rpn_box_reg: 0.0023 (0.0027)  time: 1.6448  data: 0.0133  max mem: 3797
# Epoch: [9]  [40/60]  eta: 0:00:31  lr: 0.000005  loss: 0.1514 (0.1798)  loss_classifier: 0.0220 (0.0250)  loss_box_reg: 0.0255 (0.0352)  loss_mask: 0.1064 (0.1159)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0021 (0.0026)  time: 1.5513  data: 0.0126  max mem: 3797
# Epoch: [9]  [50/60]  eta: 0:00:15  lr: 0.000005  loss: 0.1567 (0.1822)  loss_classifier: 0.0230 (0.0255)  loss_box_reg: 0.0280 (0.0362)  loss_mask: 0.1052 (0.1165)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0025 (0.0029)  time: 1.4777  data: 0.0123  max mem: 3797
# Epoch: [9]  [59/60]  eta: 0:00:01  lr: 0.000005  loss: 0.1708 (0.1794)  loss_classifier: 0.0223 (0.0248)  loss_box_reg: 0.0320 (0.0349)  loss_mask: 0.1066 (0.1161)  loss_objectness: 0.0002 (0.0010)  loss_rpn_box_reg: 0.0021 (0.0027)  time: 1.5204  data: 0.0118  max mem: 3797
# Epoch: [9] Total time: 0:01:32 (1.5432 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:36  model_time: 0.4399 (0.4399)  evaluator_time: 0.0098 (0.0098)  time: 0.7241  data: 0.2728  max mem: 3797
# Test:  [49/50]  eta: 0:00:00  model_time: 0.3309 (0.3308)  evaluator_time: 0.0051 (0.0070)  time: 0.3467  data: 0.0061  max mem: 3797
# Test: Total time: 0:00:17 (0.3521 s / it)
# Averaged stats: model_time: 0.3309 (0.3308)  evaluator_time: 0.0051 (0.0070)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.830
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.950
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.837
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.831
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.383
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.864
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.864
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.860
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.864
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.769
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.690
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.773
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.356
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.803
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.803
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.804

# %%
from google.colab.patches import cv2_imshow

img, _ = test_dataset[0]

model.eval()
with torch.no_grad():
    prediction = model([img.to(device)])

img_orig = Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
img = Image.fromarray(prediction[0]['masks'][0, 0].mul(255).byte().cpu().numpy())

# %%
img_orig = np.asarray(img_orig)
img_orig = cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB)

img = np.asarray(img)

# %%
ret, binary = cv2.threshold(img, 127, 255, 0)

# %%
contours, hierachy = cv2.findContours(binary, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

# %%
for cont in contours:
    x, y, w, h = cv2.boundingRect(cont)
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 255, 255), 2)
    cv2.rectangle(img_orig, (x, y), (x+w, y+h), (0, 0, 255), 2)

# %%
cv2_imshow(img_orig)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=564x385 at 0x7F5397589A50>
# <PIL.Image.Image image mode=L size=564x385 at 0x7F5397D04F90>
